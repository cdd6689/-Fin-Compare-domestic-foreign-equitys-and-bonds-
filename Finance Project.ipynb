# %%
from pandas import Series, DataFrame
import pandas as pd
import matplotlib.pyplot as plt
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
#Reading in Daily Stock data
df = pd.read_csv('Five ETFs.csv')
df['Date'] = pd.to_datetime(df['caldt'])
df['Year'] = pd.DatetimeIndex(df['Date']).year
df['Month'] = pd.DatetimeIndex(df['Date']).month
df[:5]
# Out:
#    crsp_fundno       caldt  dnav      dret       Date  Year  Month
# 0        11877  12/31/2008  6.35  0.005566 2008-12-31  2008     12
# 1        11877  01/02/2009  6.33 -0.003150 2009-01-02  2009      1
# 2        11877  01/05/2009  6.34  0.001580 2009-01-05  2009      1
# 3        11877  01/06/2009  6.38  0.006309 2009-01-06  2009      1
# 4        11877  01/07/2009  6.40  0.003135 2009-01-07  2009      1

# %%
mask_a = df['crsp_fundno'] == 11877
mask_b = df['crsp_fundno'] == 43528
mask_c = df['crsp_fundno'] == 29218
mask_d = df['crsp_fundno'] == 36536
mask_e = df['crsp_fundno'] == 12690

fbndx =df[mask_a]
fbndx= fbndx.set_index('Date')

eeb =df[mask_b]
eeb= eeb.set_index('Date')

gld =df[mask_c]
gld= gld.set_index('Date')

emb =df[mask_d]
emb= emb.set_index('Date')

fvd =df[mask_e]
fvd= fvd.set_index('Date')

# %%
#Commodity ETF
gld['return'] = gld['dret'] + 1 
gld_return_std = gld['return'].std()
gld['Gcum_return'] = gld['return'].shift(1).cumprod() 
gld['Return_on_100'] = gld['Gcum_return'] * 100
gld_treturn = gld['Gcum_return'].iloc[-1] - gld['Gcum_return'].iloc[2]
gld['Gann_return'] = ((1 + gld['Gcum_return']) **(252/2517)) - 1
gld_ann_stdev = gld['Gann_return'].std() * np.sqrt(252)

#sharpe ratio
gld_sharpe = gld['Gann_return'].mean()/gld_ann_stdev

plot(gld['Return_on_100'])
print('Gold ETF sharpe ratio:' ,gld_sharpe )
# Out:
# C:\Users\katch\Anaconda3\lib\site-packages\pandas\plotting\_converter.py:129: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)
#             crsp_fundno       caldt     dnav      dret  Year  Month    return  \
# Date
# 2009-02-06        29218  02/06/2009  89.7838 -0.007621  2009      2  0.992379
# 2009-02-09        29218  02/09/2009  88.0107 -0.019749  2009      2  0.980251
# 2009-02-10        29218  02/10/2009  89.4603  0.016471  2009      2  1.016471
# 2009-02-11        29218  02/11/2009  92.2376  0.031045  2009      2  1.031045
# 2009-02-12        29218  02/12/2009  92.7529  0.005587  2009      2  1.005587
# ...

# %%
gld_ann_stdev
# Out:
# 0.16544531498478426

# %%
gld['Gann_return'].tail(10)
# Out:
# Date
# 2018-12-17    0.090006
# 2018-12-18    0.090325
# 2018-12-19    0.090561
# 2018-12-20    0.091001
# 2018-12-21    0.091240
# 2018-12-24    0.091159
# 2018-12-26    0.091313
# 2018-12-27    0.091312
# 2018-12-28    0.091651
# 2018-12-31    0.092202
# Name: Gann_return, dtype: float64

# %%
#US Bonds ETF
fbndx['return'] = fbndx['dret'] + 1 
fbndx['UBcum_return'] = fbndx['return'].shift(1).cumprod() 
fbndx['Return_on_100'] = fbndx['UBcum_return'] * 100
fbndx_treturn = fbndx['UBcum_return'].iloc[-1] - fbndx['UBcum_return'].iloc[2]
fbndx['UBann_return'] = ((1 + fbndx['UBcum_return']) **(252/2517)) - 1

fbndx['UBann_return'] = ((1 + fbndx['UBcum_return']) **(252/2517)) - 1
fbndx_ann_stdev = fbndx['UBann_return'].std() * np.sqrt(252)

#sharpe ratio
fbndx_sharpe = fbndx['UBann_return'].mean()/fbndx_ann_stdev

plot(fbndx['Return_on_100'])
print('US Bonds sharpe ratio:' ,fbndx_sharpe )

# %%
#International Market ETF
eeb['return'] = eeb['dret'] + 1 
eeb['IMcum_return'] = eeb['return'].shift(1).cumprod() 
eeb['Return_on_100'] = eeb['IMcum_return'] * 100
eeb_treturn = eeb['IMcum_return'].iloc[-1] - eeb['IMcum_return'].iloc[2]
eeb['IMann_return'] = ((1 + eeb['IMcum_return']) **(252/2517)) - 1

eeb['IMann_return'] = ((1 + eeb['IMcum_return']) **(252/2517)) - 1
eeb_ann_stdev = eeb['IMann_return'].std() * np.sqrt(252)

#sharpe ratio
eeb_sharpe = eeb['IMann_return'].mean()/eeb_ann_stdev

plot(eeb['Return_on_100'])
print('Int. Market sharpe ratio:' ,eeb_sharpe )

# %%
#International Bonds ETF
emb['return'] = emb['dret'] + 1 
emb['IBcum_return'] = emb['return'].shift(1).cumprod() 
emb['Return_on_100'] = emb['IBcum_return'] * 100
emb_treturn = emb['IBcum_return'].iloc[-1] - emb['IBcum_return'].iloc[2]
emb['IBann_return'] = ((1 + emb['IBcum_return']) **(252/2517)) - 1


emb['IBann_return'] = ((1 + emb['IBcum_return']) **(252/2517)) - 1
emb_ann_stdev = emb['IBann_return'].std() * np.sqrt(252)

#sharpe ratio
emb_sharpe = emb['IBann_return'].mean()/emb_ann_stdev

plot(emb['Return_on_100'])
print('Int. Bond sharpe ratio:' ,emb_sharpe )

# %%
len(fvd)

# %%
#US MARKET ETF
fvd['return'] = fvd['dret'] + 1 
fvd['UMcum_return'] = fvd['return'].shift(1).cumprod() 
fvd['Return_on_100'] = fvd['UMcum_return'] * 100
fvd_treturn = fvd['UMcum_return'].iloc[-1] - fvd['UMcum_return'].iloc[2]
fvd['UMann_return'] = ((1 + fvd['UMcum_return']) **(252/2517)) - 1

fvd['UMann_return'] = ((1 + fvd['UMcum_return']) **(252/2517)) - 1
fvd_ann_stdev = fvd['UMann_return'].std() * np.sqrt(252)

#sharpe ratio
fvd_sharpe = fvd['UMann_return'].mean()/fvd_ann_stdev

plot(fvd['Return_on_100'])
print('US Market sharpe ratio:' ,fvd_sharpe )

# %%
fig= plt.figure(figsize=(10,6))
plt.plot(emb['Return_on_100'], marker='None', linestyle='-', label='Int. Bonds')
plt.plot(fvd['Return_on_100'], marker='None', linestyle='-', label='US Market')
plt.plot(fbndx['Return_on_100'], marker='None', linestyle='-', label='US Bonds')
plt.plot(eeb['Return_on_100'], marker='None', linestyle='-', label='Int. Market')
plt.plot(gld['Return_on_100'], marker='None', linestyle='-', label='Gold')
plt.plot(portfolio['p_Growth']*100, marker='None', linestyle='-', label='Sim. Portfolio')
plt.plot(portfolio['Return'], marker='None', linestyle='-', label='Bal. Portfolio')
xlabel('Year')
ylabel('Cumulative Returns')
legend(loc='best')
show()

# %%
#weights 
UM = .30
IM = .25
UB = .20
IB = .15
G = .10

# %%
portfolio = pd.concat([fvd['Year'], fvd['Month'], fvd['UMcum_return'], eeb['IMcum_return'], fbndx['UBcum_return'], emb['IBcum_return'], gld['Gcum_return']], axis = 1, ignore_index= False)
portfolio['Month'] = portfolio.index.to_period('M').astype(str)
portfolio['UM_Growth'] = numpy.nan
portfolio['IM_Growth'] = numpy.nan
portfolio['UB_Growth'] = numpy.nan
portfolio['IB_Growth'] = numpy.nan
portfolio['G_Growth'] = numpy.nan
portfolio['p_Growth'] = numpy.nan

# %%
portfolio['UM_Growth'] = portfolio['UMcum_return']*UM
portfolio['IM_Growth'] = portfolio['IMcum_return']*IM
portfolio['UB_Growth'] = portfolio['UBcum_return']*UB
portfolio['IB_Growth'] = portfolio['IBcum_return']*IB
portfolio['G_Growth'] = portfolio['Gcum_return']*G

portfolio['p_Growth'] = portfolio['UM_Growth']+ portfolio['IM_Growth'] + portfolio['UB_Growth'] + portfolio['IB_Growth'] + portfolio['G_Growth']

# %%
portfolio.tail(10)#[:25]
# Out:
#             Year    Month  UMcum_return  IMcum_return  UBcum_return  \
# Date
# 2018-12-17  2018  2018-12      3.417347      1.827345      1.600710
# 2018-12-18  2018  2018-12      3.323961      1.800987      1.602802
# 2018-12-19  2018  2018-12      3.335465      1.799002      1.606987
# 2018-12-20  2018  2018-12      3.305619      1.771861      1.609080
# 2018-12-21  2018  2018-12      3.276259      1.772204      1.604894
# 2018-12-24  2018  2018-12      3.236747      1.737311      1.604894
# 2018-12-26  2018  2018-12      3.135589      1.724646      1.606987
# 2018-12-27  2018  2018-12      3.231604      1.768237      1.600710
# 2018-12-28  2018  2018-12      3.256238      1.764357      1.601965
# 2018-12-31  2018  2018-12      3.258313      1.775708      1.608264
#
#             IBcum_return  Gcum_return  UM_Growth  IM_Growth  UB_Growth  \
# Date
# 2018-12-17      2.017053     1.365074   0.296372   0.396847   0.161520
# ...

# %%
portfolio['p_Return']= portfolio['p_Growth'] * 100
portfolio['p_Return'][0] = 100
# Out:
# C:\Users\katch\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
len(portfolio[portfolio['Month']=='2009-01'])
portfolio['Return'] = numpy.nan

# %%
len(portfolio[portfolio['Month']=='2009-02'])
# Out:
# 19

# %%
portfolio['Return'][0] = 100
for i in range(1,21):
    portfolio['Return'].iloc[i] = portfolio['p_Growth'].iloc[i] * portfolio['p_Return'].iloc[0]
    
for i in range(21,40):
    portfolio['Return'].iloc[i] = portfolio['p_Growth'].iloc[i] * portfolio['p_Return'].iloc[20]
# Out:
# C:\Users\katch\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\katch\Anaconda3\lib\site-packages\pandas\core\indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
months = Series(portfolio['Month'].unique())
months[1]
# Out:
# '2009-01'

# %%
lastmonth = months[2]  
for i in range(40,len(portfolio)):
    month = portfolio['Month'].iloc[i]
    if lastmonth == month:
        portfolio['Return'].iloc[i] = portfolio['p_Growth'].iloc[i] * portfolio[portfolio['Month']==lastmonth]['Return'].iloc[-1] 
    else:
        portfolio['Return'].iloc[i] = portfolio['p_Growth'].iloc[i] * portfolio[portfolio['Month']==lastmonth]['Return'].iloc[-1]

# %%
portfolio_ER = portfolio['p_Growth'].mean()
portfolio_SD = portfolio['p_Growth'].std()
p_sharpe = portfolio_ER/portfolio_SD
print(portfolio_ER,portfolio_SD, p_sharpe)
# Out:
# 1.7493351611646337 0.32336561656291135 5.409774792256855

# %%
p_sharpe*(0.5**252)
# Out:
# 1.0961215368694223e-75

# %%
# portfolio_ER = portfolio['p_Growth'].mean()
# portfolio_SD = portfolio['p_Growth'].std()
# p_sharpe = portfolio_ER/portfolio_SD
portfolio[['p_Growth', 'p_Return','Return']]#[17:65]
# Out:
#             p_Growth    p_Return      Return
# Date
# 2008-12-31       NaN  100.000000  100.000000
# 2009-01-02  1.009256  100.925625  100.925625
# 2009-01-05  1.033613  103.361277  103.361277
# 2009-01-06  1.039049  103.904914  103.904914
# 2009-01-07  1.051450  105.144955  105.144955
# 2009-01-08  1.023338  102.333807  102.333807
# 2009-01-09  1.025454  102.545382  102.545382
# 2009-01-12  1.015682  101.568177  101.568177
# 2009-01-13  0.993490   99.349000   99.349000
# 2009-01-14  0.994253   99.425284   99.425284
# 2009-01-15  0.971058   97.105782   97.105782
# 2009-01-16  0.975298   97.529819   97.529819
# 2009-01-20  0.984581   98.458091   98.458091
# 2009-01-21  0.953211   95.321052   95.321052
# 2009-01-22  0.974185   97.418536   97.418536
# 2009-01-23  0.960307   96.030742   96.030742
# 2009-01-26  0.965551   96.555057   96.555057
# 2009-01-27  0.973600   97.359974   97.359974
# 2009-01-28  0.981600   98.160037   98.160037
# 2009-01-29  1.003156  100.315610  100.315610
# ...

# %%
weights = [] 
for i in range(500): 
    numbers = random.random(5)
    x = numbers/sum(numbers)
    x=Series(x)
#     x = x.tolist()
    for v in x:
        if v <= 0.45:
            v =True
        else:
            v = False
    if v == True:
            weights.append(x)
weights[:10]
# Out:
# [0    0.308999
#  1    0.000983
#  2    0.197418
#  3    0.227109
#  4    0.265491
#  dtype: float64, 0    0.244806
#  1    0.168276
#  2    0.357955
#  3    0.220032
#  4    0.008929
#  dtype: float64, 0    0.279074
#  1    0.295242
#  2    0.125727
#  3    0.156122
#  4    0.143834
#  dtype: float64, 0    0.264882
#  1    0.052823
#  2    0.232486
#  3    0.430365
#  4    0.019444
#  dtype: float64, 0    0.326207
#  1    0.210587
#  2    0.367157
#  3    0.043490
#  4    0.052559
#  dtype: float64, 0    0.392922
#  1    0.008065
#  2    0.069756
#  3    0.327335
#  4    0.201922
#  dtype: float64, 0    0.102285
#  1    0.097381
#  2    0.087300
#  3    0.334524
#  4    0.378511
#  dtype: float64, 0    0.341423
#  1    0.170569
#  2    0.190583
#  3    0.012859
#  4    0.284566
#  dtype: float64, 0    0.230941
#  1    0.255030
#  2    0.179393
#  3    0.184717
#  4    0.149918
#  dtype: float64, 0    0.155787
#  1    0.013085
#  2    0.686674
#  3    0.095198
#  4    0.049256
# ...

# %%
sims = pd.DataFrame(columns=['E_return','S_Deviation','Sharpe_ratio'])
er = []
sd = []
sr = []
for i in range(100):
    portfolio['UM_Growth'] = portfolio['UMcum_return']*weights[i][0]
    portfolio['IM_Growth'] = portfolio['IMcum_return']*weights[i][1]
    portfolio['UB_Growth'] = portfolio['UBcum_return']*weights[i][2]
    portfolio['IB_Growth'] = portfolio['IBcum_return']*weights[i][3]
    portfolio['G_Growth'] = portfolio['Gcum_return']*weights[i][4]

    portfolio['p_Growth'] = portfolio['UM_Growth']+ portfolio['IM_Growth'] + portfolio['UB_Growth'] + portfolio['IB_Growth'] + portfolio['G_Growth']

    portfolio['Return'][0] = 100
    #Month 1 
    for x in range(1,21):
        portfolio['Return'].iloc[i] = portfolio['p_Growth'].iloc[i] * portfolio['p_Return'].iloc[0]
    #Month 2   
    for x in range(21,40):
        portfolio['Return'].iloc[i] = portfolio['p_Growth'].iloc[i] * portfolio['p_Return'].iloc[20]
    #Month 3:end
    lastmonth = months[2]  
    for x in range(40,2516):
        month = portfolio['Month'].iloc[i]
        if lastmonth == month:
            portfolio['Return'].iloc[i] = portfolio['p_Growth'].iloc[i] * portfolio[portfolio['Month']==lastmonth]['Return'].iloc[-1]
        else:
            portfolio['Return'].iloc[i] = portfolio['p_Growth'].iloc[i] * portfolio[portfolio['Month']==lastmonth]['Return'].iloc[-1]

    portfolio_ER = portfolio['p_Growth'].mean()
    er.append(portfolio_ER)
    
    portfolio_SD = portfolio['p_Growth'].std()
    sd.append(portfolio_SD)
    
    p_sharpe = portfolio_ER/portfolio_SD
    sr.append(p_sharpe)

#sims.iloc[i] = [portfolio_ER, portfolio_SD, p_sharpe ]
#     sims['E_return'][i] = portfolio_ER
#     sims['S_Deviation'][i] = portfolio_SD 
#     sims['Sharpe_ratio'][i] = p_sharpe
# Out:
# C:\Users\katch\Anaconda3\lib\site-packages\ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
ss = Series(sr)
ss.min()
# Out:
# 3.958550880464535

# %%
ss.idxmax()
# Out:
# 65

# %%
ss[65]
# Out:
# 9.593207174540458

# %%
weights[65]
# Out:
# 0    0.010074
# 1    0.202645
# 2    0.375570
# 3    0.168541
# 4    0.243170
# dtype: float64

# %%
results_frame = pd.DataFrame(results.T,columns=['ret','stdev','sharpe'])
#create scatter plot coloured by Sharpe Ratio
plt.scatter(results_frame.stdev,results_frame.ret,c=results_frame.sharpe,cmap='RdYlBu')
plt.colorbar()
